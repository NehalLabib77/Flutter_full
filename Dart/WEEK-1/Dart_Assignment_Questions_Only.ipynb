# %% [markdown]
# # Dart Programming Assignment – Questions Only
# This notebook contains questions on Dart programming concepts, from basic to advanced. No answers are included.

# %% [markdown]
# ## Section 1: Variables & Types
# 1. Declare a constant integer `constInt = 10`, a final double `finalDouble = 3.14`, and a normal String variable `name = 'Dart'`. Explain the difference between const, final, and normal variables.
# 2. Declare variables of primitive types: int, double, String, bool. Print their types using a Dart program.
# 3. Use `dynamic` and `var` variables. Assign different types sequentially and explain what happens.

# %% [markdown]
# ## Section 2: Strings
# 4. Create a string with interpolation using variables `name` and `age`. Print it.
# 5. Create a multi-line string that contains a small paragraph and print it.
# 6. Concatenate multiple strings using both `+` operator and string interpolation.

# %% [markdown]
# ## Section 3: Type Conversion & Printing
# 7. Convert an integer to double and a double to integer. Print the results.
# 8. Convert a string to int/double and vice versa. Print the results.

# %% [markdown]
# ## Section 4: Arithmetic Operators
# 9. Perform addition (+), subtraction (-), multiplication (*), division (/), integer division (~/), and modulo (%) on two numbers. Print all results.
# 10. Compute a complex expression with multiple arithmetic operators and explain the operator precedence.

# %% [markdown]
# ## Section 5: Comparison & Logical Operators
# 11. Use comparison operators `<, >, <=, >=, ==, !=` with two numbers and print the results.
# 12. Combine logical operators `&&, ||, !` to create multiple Boolean expressions.
# 13. Build a Boolean expression like `x>0 && y<10 || z==5` and explain its evaluation.

# %% [markdown]
# ## Section 6: Assignment Operators
# 14. Use `+=, -=, *=, /=, %=, ~/=` operators on a variable sequentially. Print the variable after each operation.

# %% [markdown]
# ## Section 7: Increment & Decrement
# 15. Demonstrate pre-increment (++x), post-increment (x++), pre-decrement (--x), and post-decrement (x--). Print the variable after each operation to show the difference.

# %% [markdown]
# ## Section 8: Boolean Expressions & Logical Conditions
# 16. Check if a person is eligible to vote (age >= 18) and eligible for a senior discount (age >= 60). Print appropriate messages.
# 17. Build nested conditions to categorize age groups: child, teen, adult, senior.
# 18. Use logical conditions to simulate a simple login validation system.

# %% [markdown]
# ## Section 9: Real-world & Advanced Exercises
# 19. Write a program to calculate BMI given weight and height, and categorize as underweight, normal, overweight, or obese.
# 20. Create a grading system using nested if-else statements.
# 21. Build a simple discount calculator: if total > 1000 apply 10%, else 5%.
# 22. Evaluate complex Boolean expressions involving multiple variables and operators.
# 23. Simulate a small ATM login: verify correct pin and check balance to allow withdrawal.
# 24. Create a mini program using multiple Dart features: variables, operators, type conversion, string interpolation, and logical conditions in a single program.
